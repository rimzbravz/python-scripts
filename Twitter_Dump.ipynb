# %%
#http://chimera.labs.oreilly.com/books/1234000001583/ch01.html#exploring_trending_topics

import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'd1XtQNVITtOUt8ZJtlesyk65F'
CONSUMER_SECRET = 'GITW4h5IowMyZ5g8wcOsYvfZ3Hiyc4GYaZlKXVOHIJ4EIU8UKr'
OAUTH_TOKEN = '753002126-vDiwNf7fuVEsdm9Vgz3LyiVeUQ6BmqdVcpYvszqh'
OAUTH_TOKEN_SECRET = 'nftSa0bCDPL3aqteaN2uz6FZGRVYFciT6coBGczOYsAwV'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print( twitter_api)

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
PH_WOE_ID = 23424934

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
ph_trends = twitter_api.trends.place(_id=PH_WOE_ID)

print (world_trends)
print
print (ph_trends)
# Out:
# [{'as_of': '2016-06-19T14:39:46Z', 'trends': [{'tweet_volume': 59973, 'promoted_content': None, 'query': '%23FelizDiaDelPadre', 'url': 'http://twitter.com/search?q=%23FelizDiaDelPadre', 'name': '#FelizDiaDelPadre'}, {'tweet_volume': 303982, 'promoted_content': None, 'query': '%23FathersDay', 'url': 'http://twitter.com/search?q=%23FathersDay', 'name': '#FathersDay'}, {'tweet_volume': 33411, 'promoted_content': None, 'query': '%23%E4%BD%95%E7%9C%8C%E6%B0%91%E3%81%8B%E3%83%90%E3%83%AC%E3%82%8B%E3%83%84%E3%82%A4%E3%83%BC%E3%83%88%E3%82%92%E3%81%97%E3%82%8D', 'url': 'http://twitter.com/search?q=%23%E4%BD%95%E7%9C%8C%E6%B0%91%E3%81%8B%E3%83%90%E3%83%AC%E3%82%8B%E3%83%84%E3%82%A4%E3%83%BC%E3%83%88%E3%82%92%E3%81%97%E3%82%8D', 'name': '#何県民かバレるツイートをしろ'}, {'tweet_volume': 162658, 'promoted_content': None, 'query': '%23LeMans24', 'url': 'http://twitter.com/search?q=%23LeMans24', 'name': '#LeMans24'}, {'tweet_volume': 18347, 'promoted_content': None, 'query': '%23Top5OneDirection', 'url': 'http
# ...

# %%
import json

print (json.dumps(ph_trends, indent = 1))
# Out:
# [
#  {
#   "as_of": "2016-06-19T14:39:48Z",
#   "trends": [
#    {
#     "tweet_volume": 10249,
#     "promoted_content": null,
#     "query": "%23KMJS11",
#     "url": "http://twitter.com/search?q=%23KMJS11",
#     "name": "#KMJS11"
#    },
#    {
#     "tweet_volume": null,
#     "promoted_content": null,
#     "query": "%23TVK3fathersday",
#     "url": "http://twitter.com/search?q=%23TVK3fathersday",
#     "name": "#TVK3fathersday"
#    },
#    {
#     "tweet_volume": null,
#     "promoted_content": null,
#     "query": "%23AskBret",
#     "url": "http://twitter.com/search?q=%23AskBret",
#     "name": "#AskBret"
#    },
#    {
#     "tweet_volume": null,
#     "promoted_content": null,
#     "query": "%23OPMRicoJPuno",
#     "url": "http://twitter.com/search?q=%23OPMRicoJPuno",
#     "name": "#OPMRicoJPuno"
#    },
#    {
#     "tweet_volume": 12755,
#     "promoted_content": null,
#     "query": "%23OneMusicYENG10",
#     "url": "http://twitter.com/search?q=%23OneMusicYENG10",
# ...

# %%
world_trends_set = set([trend['name'] for trend in world_trends[0]['trends']])
ph_trends_set = set([trend['name'] for trend in ph_trends[0]['trends']])
common_trends = world_trends_set.intersection(ph_trends_set)

print( common_trends )
# Out:
# {'#Top5OneDirection', '#10YearsOfTaylorSwift', '#KMJS11'}
